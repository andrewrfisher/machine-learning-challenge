# %%
#import dependencies

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
#read csv and perform basic cleaning

df = pd.read_csv("cumulative.csv")
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.002160  ...           -81.0      4.467           0.064
# 1          0.003520  ...           -81.0      4.467           0.064
# 2          0.000581  ...          -176.0      4.544           0.044
# 3          0.000115  ...          -174.0      4.564           0.053
# 4          0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 41 columns]

# %%
#select your features (columns)
target = df["koi_disposition"]
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2     1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4     3.761000e-06    -3.761000e-06   171.595550          0.001130
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.002160  ...           -81.0      4.467           0.064
# 1         -0.003520  ...           -81.0      4.467           0.064
# 2         -0.000581  ...          -176.0      4.544           0.044
# 3         -0.000115  ...          -174.0      4.564           0.053
# 4         -0.001130  ...          -211.0      4.438           0.070
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.096     0.927          0.105         -0.061  291.93423
# 2          -0.176     0.868          0.233         -0.078  297.00482
# 3          -0.168     0.791          0.201         -0.067  285.53461
# 4          -0.210     1.046          0.334         -0.133  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.141651      15.347
# 2  48.134129      15.436
# 3  48.285210      15.597
# 4  48.226200      15.509
#
# [5 rows x 40 columns]

# %%
#split training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
#pre-processing

# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
#y_scaler = MinMaxScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
#y_train_scaled = y_scaler.transform(y_train)
#y_test_scaled = y_scaler.transform(y_test)

# %%
#random forest
rf = RandomForestClassifier()
rf = rf.fit(X_train_scaled, y_train)
print(rf.score(X_train_scaled, y_train))
print(rf.score(X_test_scaled, y_test))
# Out:
# 1.0
# 0.8929551692589204

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.11037399270460643, 'koi_fpflag_co'),
#  (0.09628775786228098, 'koi_fpflag_nt'),
#  (0.06235439714471469, 'koi_fpflag_ss'),
#  (0.05888989390113698, 'koi_model_snr'),
#  (0.04798356657401055, 'koi_prad'),
#  (0.03751492857549612, 'koi_prad_err2'),
#  (0.036967544570369104, 'koi_duration_err1'),
#  (0.0363272127992839, 'koi_steff_err1'),
#  (0.03441047204299981, 'koi_fpflag_ec'),
#  (0.03369361196159539, 'koi_prad_err1'),
#  (0.029278193176704437, 'koi_duration_err2'),
#  (0.025646191945011828, 'koi_steff_err2'),
#  (0.02380252688097279, 'koi_period'),
#  (0.023598200016509262, 'koi_time0bk_err1'),
#  (0.02237931568358894, 'koi_duration'),
#  (0.021306757441106546, 'koi_time0bk_err2'),
#  (0.019313845345232335, 'koi_depth'),
#  (0.01765093639145658, 'koi_period_err2'),
#  (0.017173232476585407, 'koi_period_err1'),
#  (0.016814104740986054, 'koi_teq'),
#  (0.01675738536140197, 'koi_insol_err1'),
#  (0.015831395403623664, 'koi_insol'),
#  (0.015332153856727699, 'koi_impact'),
#  (0.015135471718116801, 'koi_time0bk'),
#  (0.01321187314060775, 'koi_insol_err2'),
#  (0.012909034182652688, 'koi_depth_err1'),
#  (0.012663681311268911, 'koi_depth_err2'),
#  (0.011973872184568428, 'ra'),
#  (0.011936468838749527, 'koi_srad_err1'),
#  (0.0114233270089847, 'dec'),
#  (0.01083938867179943, 'koi_impact_err2'),
#  (0.010770962039764735, 'koi_impact_err1'),
#  (0.010408881326868992, 'koi_slogg_err2'),
#  (0.010355135238797586, 'koi_kepmag'),
#  (0.009688104675463128, 'koi_steff'),
#  (0.009439458929619686, 'koi_srad'),
#  (0.00902331442532085, 'koi_srad_err2'),
#  (0.008793519655430381, 'koi_slogg'),
#  (0.008538476201393691, 'koi_slogg_err1'),
#  (0.003201413594191224, 'koi_tce_plnt_num')]

# %%
# Create the GridSearchCV model
param_grid = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... max_depth=125, n_estimators=250, score=0.894, total=   4.5s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.5s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.893, total=   4.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    9.1s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.902, total=   4.6s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.892, total=   4.3s
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.896, total=   4.3s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.889, total=   5.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.895, total=   5.3s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.899, total=   5.1s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.892, total=   5.2s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.899, total=   5.3s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.893, total=   6.1s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.897, total=   6.2s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.898, total=   6.2s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.889, total=   6.2s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.895, total=   6.2s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.891, total=   4.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.899, total=   4.4s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.906, total=   4.5s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.893, total=   4.5s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.895, total=   4.5s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.894, total=   6.3s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.894, total=   5.7s
# [CV] max_depth=150, n_estimators=300 .................................
